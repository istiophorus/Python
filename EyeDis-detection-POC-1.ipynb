# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers
import os
import matplotlib.pyplot as plt
import numpy as np
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
import keras.applications.efficientnet
from keras.applications.efficientnet import EfficientNetB7
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D
from keras.layers.convolutional import Conv2D
#from keras.layers.advanced_activations import LeakyReLU
from keras.layers import LeakyReLU
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, CSVLogger
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras.applications.efficientnet import EfficientNetB7
from keras.applications.efficientnet_v2 import EfficientNetV2L
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications.resnet_v2 import ResNet152V2
from keras.applications.densenet import DenseNet121
from keras.applications.resnet import ResNet50

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.__version__
# Out:
# '2.9.3'

# %%
data_base_train_folder = 'd:/Dane/retinaldiseaseclassification/prepared/ARMD/Train'
data_base_valid_folder = 'd:/Dane/retinaldiseaseclassification/prepared/ARMD/Validate'
data_base_test_folder = 'd:/Dane/retinaldiseaseclassification/prepared/ARMD/Test'

# %%
training_workspace_folder = "d:/Dane/retinaldiseaseclassification/prepared/workspace/"

# %%
def create_model_from_vgg16():
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224,3))
    
    for layer in vgg16.layers:
        layer.trainable = False
        
    new_model = tf.keras.models.Sequential([
        vgg16,
        Flatten(),    
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_inceptionV3():
    inceptionV3 = InceptionV3(include_top=False, weights='imagenet', input_shape=(224, 224,3))
    
    for layer in inceptionV3.layers:
        layer.trainable = False
        
    new_model = tf.keras.models.Sequential([
        inceptionV3,
        BatchNormalization(),
        Flatten(),  
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_inceptionV3_B():
    inceptionV3 = InceptionV3(include_top=False, weights='imagenet', input_shape=(224, 224,3))
    
    for layer in inceptionV3.layers:
        layer.trainable = False
        
    new_model = tf.keras.models.Sequential([
        inceptionV3,
        #BatchNormalization(),
        Flatten(),  
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),        
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_inceptionV3_D():
    inceptionV3 = InceptionV3(include_top=False, weights='imagenet', input_shape=(224, 224,3))
    
    for layer in inceptionV3.layers:
        layer.trainable = False
        
    new_model = tf.keras.models.Sequential([
        inceptionV3,
        BatchNormalization(),
        Flatten(),  
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),        
        Dense(16),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),        
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_inceptionV3_C():
    inceptionV3 = InceptionV3(include_top=False, weights='imagenet', input_shape=(224, 224,3))
    
    for layer in inceptionV3.layers:
        layer.trainable = False
        
    new_model = tf.keras.models.Sequential([
        inceptionV3,
        Flatten(),  
        Dense(256),
        LeakyReLU(alpha = 0.01),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_efficientnet_B():
    base_model = EfficientNetB7(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(16),
        LeakyReLU(alpha = 0.01),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_efficientnet_C():
    base_model = EfficientNetB7(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(512),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(16),
        LeakyReLU(alpha = 0.01),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_InceptionResNetV2_A():
    base_model = InceptionResNetV2(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(512),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(16),
        LeakyReLU(alpha = 0.01),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_VGG19_A():
    base_model = VGG19(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(512),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(16),
        LeakyReLU(alpha = 0.01),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_VGG19_B():
    base_model = VGG19(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(1024),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(512),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(16),
        LeakyReLU(alpha = 0.01),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_VGG19_C():
    base_model = VGG19(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(1024, activation="sigmoid"),
        Dropout(0.2),
        Dense(512, activation="sigmoid"),
        Dropout(0.2),
        Dense(256, activation="sigmoid"),
        Dropout(0.2),
        Dense(16, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_EfficientNetV2L_A():
    base_model = EfficientNetV2L(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(1024, activation="sigmoid"),
        Dropout(0.2),
        Dense(512, activation="sigmoid"),
        Dropout(0.2),
        Dense(256, activation="sigmoid"),
        Dropout(0.2),
        Dense(16, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_EfficientNetV2L_B():
    base_model = EfficientNetV2L(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(1024, activation="relu"),
        Dropout(0.2),
        Dense(512, activation="relu"),
        Dropout(0.2),
        Dense(256, activation="relu"),
        Dropout(0.2),
        Dense(16, activation="relu"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_EfficientNetV2L_C():
    base_model = EfficientNetV2L(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(2048, activation="sigmoid"),
        Dropout(0.2),
        Dense(1024, activation="sigmoid"),
        Dropout(0.2),
        Dense(512, activation="sigmoid"),
        Dropout(0.2),
        Dense(256, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_vgg16_B():
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224,3))
    
    for layer in vgg16.layers:
        layer.trainable = False
        
    new_model = tf.keras.models.Sequential([
        vgg16,
        Flatten(),    
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_vgg16_C():
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224,3))
    
    for layer in vgg16.layers:
        layer.trainable = False
        
    new_model = tf.keras.models.Sequential([
        vgg16,
        Flatten(),    
        BatchNormalization(),
        Dense(1024, activation="sigmoid"),
        Dropout(0.2),
        Dense(512, activation="sigmoid"),
        Dropout(0.2),
        Dense(256, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_efficientnet_D():
    base_model = EfficientNetB7(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(1024, activation="sigmoid"),
        Dropout(0.2),
        Dense(512, activation="sigmoid"),
        Dropout(0.2),
        Dense(256, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_efficientnet_E():
    base_model = EfficientNetB7(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(512),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(16),
        LeakyReLU(alpha = 0.01),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_vgg16_D():
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224,3))
    
    for layer in vgg16.layers:
        layer.trainable = False
        
    new_model = tf.keras.models.Sequential([
        vgg16,
        Flatten(),    
        BatchNormalization(),
        Dense(1024, activation="sigmoid"),
        Dropout(0.2),
        Dense(512, activation="sigmoid"),
        Dropout(0.2),
        Dense(256, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_vgg16_E():
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224,3))
    
    for layer in vgg16.layers:
        layer.trainable = False
        
    vgg16.layers[-1].trainable = True
    vgg16.layers[-2].trainable = True
    vgg16.layers[-3].trainable = True
        
    new_model = tf.keras.models.Sequential([
        vgg16,
        Flatten(),    
        BatchNormalization(),
        Dense(1024, activation="sigmoid"),
        Dropout(0.2),
        Dense(512, activation="sigmoid"),
        Dropout(0.2),
        Dense(256, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_vgg16_E():
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224,3))
    
    for layer in vgg16.layers:
        layer.trainable = False
        
    vgg16.layers[-1].trainable = True
    vgg16.layers[-2].trainable = True
    vgg16.layers[-3].trainable = True
        
    new_model = tf.keras.models.Sequential([
        vgg16,
        Flatten(),    
        BatchNormalization(),
        Dense(1024, activation="sigmoid"),
        Dropout(0.2),
        Dense(512, activation="sigmoid"),
        Dropout(0.2),
        Dense(256, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return new_model

# %%
def create_model_from_vgg16_F():
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224,3))

    for layer in vgg16.layers:
        layer.trainable = False

    new_model = tf.keras.models.Sequential([
        vgg16,
        Conv2D(filters = 512, kernel_size = (3,3), padding = "same", activation = "relu"),
        Conv2D(filters = 512, kernel_size = (3,3), padding = "same", activation = "relu"),
        #Conv2D(filters = 512, kernel_size = (3,3), padding = "same", activation = "relu"),
        MaxPooling2D(pool_size=(2,2), strides=(2,2)),
        Flatten(),    
        BatchNormalization(),
        #Dense(1024, activation="sigmoid"),
        #Dropout(0.2),
        Dense(512, activation="sigmoid"),
        Dropout(0.2),
        Dense(256, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])

    return new_model

# %%
def create_model_from_vgg16_G():
    vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224,3))

    for layer in vgg16.layers:
        layer.trainable = False

    new_model = tf.keras.models.Sequential([
        vgg16,
        Flatten(),    
        BatchNormalization(),
        Dense(4096, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])

    return (new_model, keras.applications.vgg16.preprocess_input)

# %%
def create_model_from_ResNet152V2_A():
    base_model = ResNet152V2(include_top=False, weights='imagenet', input_shape=(224, 224,3))

    for layer in base_model.layers:
        layer.trainable = False

    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),    
        BatchNormalization(),
        Dense(1024, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])

    return (new_model, keras.applications.resnet_v2.preprocess_input)

# %%
def create_model_from_efficientnet_C():
    base_model = EfficientNetB7(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),  
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(256),
        LeakyReLU(alpha = 0.01),
        BatchNormalization(),
        Dense(16),
        LeakyReLU(alpha = 0.01),
        Dropout(0.3),
        Dense(2, activation='softmax')
    ])
    
    return (new_model, keras.applications.efficientnet_v2.preprocess_input)

# %%
def create_model_from_DenseNet121_C():
    base_model = DenseNet121(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        GlobalAveragePooling2D(),  
        Dropout(0.5),
        Dense(2, activation='softmax')
    ])
    
    return (new_model, keras.applications.densenet.preprocess_input)

# %%
def create_model_from_DenseNet121_D():
    base_model = DenseNet121(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),    
        BatchNormalization(),
        Dense(4096, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return (new_model, keras.applications.densenet.preprocess_input)

# %%
def create_model_from_ResNet50_A():
    base_model = ResNet50(
        include_top = False,
        weights = "imagenet",
        input_shape = (224, 224,3))
    
    for layer in base_model.layers:
        layer.trainable = False
    
    new_model = tf.keras.models.Sequential([
        base_model,
        Flatten(),    
        BatchNormalization(),
        Dense(1024, activation="sigmoid"),
        Dropout(0.2),
        Dense(128, activation="sigmoid"),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])
    
    return (new_model, keras.applications.resnet.preprocess_input)

# %%
checkpointer = ModelCheckpoint(filepath = training_workspace_folder +'best_val_loss_weights.h5', verbose = 1, monitor = 'val_loss', mode = 'auto', save_best_only = True) #save at each epoch if the validation decreased
checkpointer2 = ModelCheckpoint(filepath = training_workspace_folder +'best_accuracy_weights.h5', verbose = 1, monitor = 'accuracy', mode = 'auto', save_best_only = True) #save at each epoch if the validation decreased
checkpointer3 = ModelCheckpoint(filepath = training_workspace_folder +'best_val_accuracy_weights.h5', verbose = 1, monitor = 'val_accuracy', mode = 'auto', save_best_only = True) #save at each epoch if the validation decreased

# %%
(model, selected_preprocessing_function) = create_model_from_ResNet50_A()

# %%
selected_preprocessing_function
# Out:
# <function keras.applications.resnet.preprocess_input(x, data_format=None)>

# %%
train_generator = ImageDataGenerator(
    zoom_range=[0.8, 1.2],
    rotation_range = 90.0,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    vertical_flip = True,
    preprocessing_function = selected_preprocessing_function
).flow_from_directory(
    directory = data_base_train_folder,
    class_mode = 'categorical',
    target_size = (224,224),
    classes = ['ARMD0', 'ARMD1'],
    batch_size = 32)
# Out:
# Found 1920 images belonging to 2 classes.

# %%
validation_generator = ImageDataGenerator(
    zoom_range=[0.8, 1.2],
    rotation_range = 90.0,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    vertical_flip = True,
    preprocessing_function = selected_preprocessing_function
).flow_from_directory(
    directory = data_base_valid_folder,
    class_mode = 'categorical',
    target_size = (224,224),
    classes = ['ARMD0', 'ARMD1'],
    batch_size = 32)
# Out:
# Found 640 images belonging to 2 classes.

# %%
test_generator = ImageDataGenerator(
    preprocessing_function = selected_preprocessing_function
).flow_from_directory(
    directory = data_base_test_folder,
    class_mode = 'categorical',
    target_size = (224,224),
    classes = ['ARMD0', 'ARMD1'],
    batch_size = 32)
# Out:
# Found 640 images belonging to 2 classes.

# %%
def scheduler_I(epoch, lr):
    if epoch < 10:
        return 0.001
    
    if epoch < 20:
        return 0.0005
    
    if epoch < 50:
        return 0.0001
    
    return 0.00005

# %%
def scheduler_II(epoch, lr):
    if epoch < 10:
        return 0.001
    
    if epoch < 20:
        return 0.0001
    
    if epoch < 50:
        return 0.00001
    
    return 0.000005

# %%
learning_rate_scheduler_callback = LearningRateScheduler(scheduler_I)

# %%
csv_logger = CSVLogger('d:/Dane/retinaldiseaseclassification/prepared/workspace/training.log')

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
json_string = model.to_json()
open(training_workspace_folder + 'TL_model_architecture.json', 'w').write(json_string)
history = model.fit_generator(
    train_generator,
    validation_data = validation_generator,
    epochs = 20,
    callbacks = [checkpointer, checkpointer2, checkpointer3, learning_rate_scheduler_callback, csv_logger]
)
# Out:
# C:\Users\ax\AppData\Local\Temp\ipykernel_11700\957810706.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/20
# 60/60 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9479
# Epoch 1: val_loss did not improve from 0.19373
#
# Epoch 1: accuracy improved from 0.92604 to 0.94792, saving model to d:/Dane/retinaldiseaseclassification/prepared/workspace\best_accuracy_weights.h5
#
# Epoch 1: val_accuracy did not improve from 0.94063
# 60/60 [==============================] - 205s 3s/step - loss: 0.2005 - accuracy: 0.9479 - val_loss: 0.2158 - val_accuracy: 0.9406 - lr: 0.0010
# Epoch 2/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1887 - accuracy: 0.9474
# Epoch 2: val_loss did not improve from 0.19373
#
# Epoch 2: accuracy did not improve from 0.94792
#
# Epoch 2: val_accuracy did not improve from 0.94063
# 60/60 [==============================] - 200s 3s/step - loss: 0.1887 - accuracy: 0.9474 - val_loss: 0.2163 - val_accuracy: 0.9406 - lr: 0.0010
# Epoch 3/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1951 - accuracy: 0.9469
# Epoch 3: val_loss did not improve from 0.19373
#
# Epoch 3: accuracy did not improve from 0.94792
#
# Epoch 3: val_accuracy did not improve from 0.94063
# 60/60 [==============================] - 200s 3s/step - loss: 0.1951 - accuracy: 0.9469 - val_loss: 0.2031 - val_accuracy: 0.9406 - lr: 0.0010
# Epoch 4/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1825 - accuracy: 0.9474
# Epoch 4: val_loss did not improve from 0.19373
#
# Epoch 4: accuracy did not improve from 0.94792
#
# Epoch 4: val_accuracy did not improve from 0.94063
# 60/60 [==============================] - 200s 3s/step - loss: 0.1825 - accuracy: 0.9474 - val_loss: 0.1956 - val_accuracy: 0.9406 - lr: 0.0010
# Epoch 5/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1803 - accuracy: 0.9469
# Epoch 5: val_loss improved from 0.19373 to 0.17450, saving model to d:/Dane/retinaldiseaseclassification/prepared/workspace\best_val_loss_weights.h5
#
# Epoch 5: accuracy did not improve from 0.94792
#
# Epoch 5: val_accuracy did not improve from 0.94063
# 60/60 [==============================] - 202s 3s/step - loss: 0.1803 - accuracy: 0.9469 - val_loss: 0.1745 - val_accuracy: 0.9406 - lr: 0.0010
# Epoch 6/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1792 - accuracy: 0.9469
# Epoch 6: val_loss did not improve from 0.17450
#
# Epoch 6: accuracy did not improve from 0.94792
#
# Epoch 6: val_accuracy did not improve from 0.94063
# 60/60 [==============================] - 199s 3s/step - loss: 0.1792 - accuracy: 0.9469 - val_loss: 0.1759 - val_accuracy: 0.9406 - lr: 0.0010
# Epoch 7/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9479
# Epoch 7: val_loss did not improve from 0.17450
#
# Epoch 7: accuracy did not improve from 0.94792
#
# Epoch 7: val_accuracy improved from 0.94063 to 0.94375, saving model to d:/Dane/retinaldiseaseclassification/prepared/workspace\best_val_accuracy_weights.h5
# 60/60 [==============================] - 202s 3s/step - loss: 0.1694 - accuracy: 0.9479 - val_loss: 0.1788 - val_accuracy: 0.9438 - lr: 0.0010
# Epoch 8/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9500
# Epoch 8: val_loss did not improve from 0.17450
#
# Epoch 8: accuracy improved from 0.94792 to 0.95000, saving model to d:/Dane/retinaldiseaseclassification/prepared/workspace\best_accuracy_weights.h5
#
# Epoch 8: val_accuracy did not improve from 0.94375
# 60/60 [==============================] - 202s 3s/step - loss: 0.1694 - accuracy: 0.9500 - val_loss: 0.1817 - val_accuracy: 0.9438 - lr: 0.0010
# Epoch 9/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9505
# Epoch 9: val_loss did not improve from 0.17450
#
# Epoch 9: accuracy improved from 0.95000 to 0.95052, saving model to d:/Dane/retinaldiseaseclassification/prepared/workspace\best_accuracy_weights.h5
#
# Epoch 9: val_accuracy did not improve from 0.94375
# 60/60 [==============================] - 201s 3s/step - loss: 0.1645 - accuracy: 0.9505 - val_loss: 0.1918 - val_accuracy: 0.9406 - lr: 0.0010
# Epoch 10/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1646 - accuracy: 0.9500
# Epoch 10: val_loss improved from 0.17450 to 0.16426, saving model to d:/Dane/retinaldiseaseclassification/prepared/workspace\best_val_loss_weights.h5
#
# Epoch 10: accuracy did not improve from 0.95052
#
# Epoch 10: val_accuracy did not improve from 0.94375
# 60/60 [==============================] - 202s 3s/step - loss: 0.1646 - accuracy: 0.9500 - val_loss: 0.1643 - val_accuracy: 0.9438 - lr: 0.0010
# Epoch 11/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1651 - accuracy: 0.9479
# Epoch 11: val_loss did not improve from 0.16426
#
# Epoch 11: accuracy did not improve from 0.95052
#
# Epoch 11: val_accuracy did not improve from 0.94375
# 60/60 [==============================] - 200s 3s/step - loss: 0.1651 - accuracy: 0.9479 - val_loss: 0.1892 - val_accuracy: 0.9406 - lr: 5.0000e-04
# Epoch 12/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9505
# Epoch 12: val_loss did not improve from 0.16426
#
# Epoch 12: accuracy did not improve from 0.95052
#
# Epoch 12: val_accuracy improved from 0.94375 to 0.94531, saving model to d:/Dane/retinaldiseaseclassification/prepared/workspace\best_val_accuracy_weights.h5
# 60/60 [==============================] - 202s 3s/step - loss: 0.1597 - accuracy: 0.9505 - val_loss: 0.1663 - val_accuracy: 0.9453 - lr: 5.0000e-04
# Epoch 13/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9531
# Epoch 13: val_loss did not improve from 0.16426
#
# Epoch 13: accuracy improved from 0.95052 to 0.95312, saving model to d:/Dane/retinaldiseaseclassification/prepared/workspace\best_accuracy_weights.h5
#
# Epoch 13: val_accuracy did not improve from 0.94531
# 60/60 [==============================] - 202s 3s/step - loss: 0.1563 - accuracy: 0.9531 - val_loss: 0.1842 - val_accuracy: 0.9359 - lr: 5.0000e-04
# Epoch 14/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.9490
# Epoch 14: val_loss did not improve from 0.16426
#
# Epoch 14: accuracy did not improve from 0.95312
#
# Epoch 14: val_accuracy did not improve from 0.94531
# 60/60 [==============================] - 199s 3s/step - loss: 0.1581 - accuracy: 0.9490 - val_loss: 0.1838 - val_accuracy: 0.9406 - lr: 5.0000e-04
# Epoch 15/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.9516
# Epoch 15: val_loss did not improve from 0.16426
#
# Epoch 15: accuracy did not improve from 0.95312
#
# Epoch 15: val_accuracy did not improve from 0.94531
# 60/60 [==============================] - 200s 3s/step - loss: 0.1520 - accuracy: 0.9516 - val_loss: 0.1821 - val_accuracy: 0.9359 - lr: 5.0000e-04
# Epoch 16/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9495
# Epoch 16: val_loss did not improve from 0.16426
#
# Epoch 16: accuracy did not improve from 0.95312
#
# Epoch 16: val_accuracy did not improve from 0.94531
# 60/60 [==============================] - 200s 3s/step - loss: 0.1483 - accuracy: 0.9495 - val_loss: 0.1733 - val_accuracy: 0.9391 - lr: 5.0000e-04
# Epoch 17/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9495
# Epoch 17: val_loss did not improve from 0.16426
#
# Epoch 17: accuracy did not improve from 0.95312
#
# Epoch 17: val_accuracy did not improve from 0.94531
# 60/60 [==============================] - 199s 3s/step - loss: 0.1543 - accuracy: 0.9495 - val_loss: 0.1909 - val_accuracy: 0.9406 - lr: 5.0000e-04
# Epoch 18/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1476 - accuracy: 0.9505
# Epoch 18: val_loss did not improve from 0.16426
#
# Epoch 18: accuracy did not improve from 0.95312
#
# Epoch 18: val_accuracy did not improve from 0.94531
# 60/60 [==============================] - 198s 3s/step - loss: 0.1476 - accuracy: 0.9505 - val_loss: 0.1899 - val_accuracy: 0.9391 - lr: 5.0000e-04
# Epoch 19/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9516
# Epoch 19: val_loss improved from 0.16426 to 0.14841, saving model to d:/Dane/retinaldiseaseclassification/prepared/workspace\best_val_loss_weights.h5
#
# Epoch 19: accuracy did not improve from 0.95312
#
# Epoch 19: val_accuracy improved from 0.94531 to 0.94687, saving model to d:/Dane/retinaldiseaseclassification/prepared/workspace\best_val_accuracy_weights.h5
# 60/60 [==============================] - 205s 3s/step - loss: 0.1490 - accuracy: 0.9516 - val_loss: 0.1484 - val_accuracy: 0.9469 - lr: 5.0000e-04
# Epoch 20/20
# 60/60 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9526
# Epoch 20: val_loss did not improve from 0.14841
#
# Epoch 20: accuracy did not improve from 0.95312
#
# Epoch 20: val_accuracy did not improve from 0.94687
# 60/60 [==============================] - 199s 3s/step - loss: 0.1486 - accuracy: 0.9526 - val_loss: 0.1794 - val_accuracy: 0.9391 - lr: 5.0000e-04

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  batch_normalization_1 (Batc  (None, 100352)           401408
#  hNormalization)
#
#  dense_3 (Dense)             (None, 1024)              102761472
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 128)               131200
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 126,882,050
# Trainable params: 103,093,634
# Non-trainable params: 23,788,416
# _________________________________________________________________

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
scoreSeg = model.evaluate_generator(test_generator, 400)
# Out:
# C:\Users\ax\AppData\Local\Temp\ipykernel_11700\2230227760.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   scoreSeg = model.evaluate_generator(test_generator, 400)
