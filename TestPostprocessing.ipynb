# %%
import requests
from pprint import pprint
from PIL import Image
import os
import shutil
import cv2
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def process_image(input_path):
    with open(input_path, 'rb') as f:
        r = requests.post('http://127.0.0.1:5000/api/v1/segmentation/opticdisk', files = {'file': ('0792_test.tif', f, 'image/tiff', {'Expires': '0'})})
        print(r)    
        if r.status_code != 200:
            raise ValueError("Unexpected result")
            
        outputFileName = r.content
        return outputFileName

# %%
def read_gif_by_cv2(pathIn):
    cap = cv2.VideoCapture(pathIn)
    ret, image = cap.read()
    cap.release()
    return image

# %%
def dump_to_pickle(obj, target_path):
    target_file = open(target_path, 'wb')
    pickle.dump(obj, target_file)
    target_file.close()

# %%
def compare_images_cv2_fast(cv2image1, cv2image2):
    
    rows1,cols1,_ = cv2image1.shape
    rows2,cols2,_ = cv2image2.shape
    
    if rows1 != rows2 or cols1 != cols2:
        print(rows1)
        print(rows2)
        print(cols1)
        print(cols2)
        raise ValueError("Images have different size")
        
    cv2image1int = cv2image1.astype(int)
    cv2image2int = cv2image2.astype(int)
    
    all_count = cv2image1int.shape[0] * cv2image1int.shape[1]
    diff = (cv2image1int - cv2image2int)
    diff = np.abs(diff)
    diff_sum = diff.sum() / (255 * cv2image1int.shape[2])
    equal_count = (np.sign((cv2image1.astype(int) - cv2image2.astype(int))) == 0).astype(int).sum() / cv2image1int.shape[2]
    
    return (equal_count, diff_sum, all_count, equal_count + diff_sum)

# %%
input_dir = 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/'
expected_result_dir = 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/'

# %%
output_dir = 'd:/Dane/test_out/'

# %%
files = os.listdir(input_dir)
res_map = {}
for file_name in files:
    expected_result_file = file_name
    full_file_name = input_dir +file_name
    expected_result_file = expected_result_file.replace('_training.tif', '_manual1.gif')
    full_expected_result_file = expected_result_dir + expected_result_file
    output_file = process_image(full_file_name)
    res_map[file_name] = (full_file_name, output_file, full_expected_result_file)
    print(res_map[file_name])
# Out:
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0001_training.tif', b'd:/Fundus/uploads\\55fbfd52-3529-42ee-b6d6-09c92dcafd3b.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0001_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0002_training.tif', b'd:/Fundus/uploads\\e793eca1-6fbc-4f60-a382-fae13a2ea976.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0002_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0003_training.tif', b'd:/Fundus/uploads\\c09e11f3-94a0-4c0d-8af8-e97ed02f6ca8.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0003_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0004_training.tif', b'd:/Fundus/uploads\\7cda40d3-ffbe-4d7b-98b3-184875fac48b.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0004_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0005_training.tif', b'd:/Fundus/uploads\\664236dd-9c8c-4554-849f-6efac2131a45.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0005_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0006_training.tif', b'd:/Fundus/uploads\\bb04943b-2fd9-4e73-ab58-4ffce9baa5e3.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0006_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0007_training.tif', b'd:/Fundus/uploads\\26e636a0-e864-4885-9f3e-e05edb70b566.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0007_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0008_training.tif', b'd:/Fundus/uploads\\a9584d45-96d7-4c41-b23e-92217d5bf0aa.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0008_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0009_training.tif', b'd:/Fundus/uploads\\3c7147b4-8cee-43a7-8f13-1e3e57558b42.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0009_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0010_training.tif', b'd:/Fundus/uploads\\ee90acb4-cbb2-4375-aa10-fb8212956a87.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0010_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0011_training.tif', b'd:/Fundus/uploads\\520ab7b8-5734-4308-9f53-2439c76be0d4.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0011_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0012_training.tif', b'd:/Fundus/uploads\\11679a4b-1ad4-4c16-a9cd-9a23d1abbae1.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/
training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0396_training.tif', b'd:/Fundus/uploads\\80ee7352-05fc-4762-a58c-1bd73627c93f.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0396_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0397_training.tif', b'd:/Fundus/uploads\\3a51c5a7-fb68-43e5-a552-33566631585b.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0397_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0398_training.tif', b'd:/Fundus/uploads\\01ee8aeb-796a-40c3-9bd4-9c48a8aec0d6.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0398_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0399_training.tif', b'd:/Fundus/uploads\\20b9d46d-f6e7-4a97-9755-8eddd238a0d0.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0399_training.tif')
# <Response [200]>
# ('c:/Users/ax/retina-unet-master-disc/DRIVE/training/images/0400_training.tif', b'd:/Fundus/uploads\\8b130b03-1074-4cb1-adaa-af5f9b5307b6.tif_predicted.png', 'c:/Users/ax/retina-unet-master-disc/DRIVE/training/1st_manual/0400_training.tif')

# %%
res_map_file = open('d:/res_map.pickle', 'wb')
pickle.dump(res_map, res_map_file)
res_map_file.close()

# %%
res_values = [v for v in res_map.values()]

# %%
all_results = {}
images_cache = {}
all_count = 0

for ix in range(0, 255):
    print('Checking treshold ' + str(ix))
    all_results[ix] = []
    for im in res_values:
        _, pr, ex = im
        ex = ex.replace('_training.tif', '_manual1.gif')
        pr = pr.decode("utf-8")
        #print(ex)
        #print(pr)
        
        if ex in images_cache:
            exp_img = images_cache[ex]
        else:
            exp_img = read_gif_by_cv2(ex)
            images_cache[ex] = exp_img
        
        img = cv2.imread(pr)
        ret_val, img_out = cv2.threshold(img, ix, 255, cv2.THRESH_BINARY)

        comparison_result = compare_images_cv2_fast(exp_img, img_out)
        all_results[ix].append(comparison_result)
        all_count = all_count + 1
        if all_count % 100 == 0:
            print('all count ' + str(all_count))
# Out:
# Checking treshold 0
# all count 100
# all count 200
# all count 300
# all count 400
# Checking treshold 1
# all count 500
# all count 600
# all count 700
# all count 800
# Checking treshold 2
# all count 900
# all count 1000
# all count 1100
# all count 1200
# Checking treshold 3
# all count 1300
# all count 1400
# all count 1500
# all count 1600
# Checking treshold 4
# all count 1700
# all count 1800
# all count 1900
# all count 2000
# Checking treshold 5
# all count 2100
# all count 2200
# all count 2300
# all count 2400
# Checking treshold 6
# all count 2500
# all count 2600
# all count 2700
# all count 2800
# Checking treshold 7
# all count 2900
# all count 3000
# all count 3100
# all count 3200
# Checking treshold 8
# all count 3300
# all count 3400
# all count 3500
# all count 3600
# Checking treshold 9
# all count 3700
# all count 3800
# all count 3900
# all count 4000
# Checking treshold 10
# all count 4100
# all count 4200
# all count 4300
# all count 4400
# Checking treshold 11
# all count 4500
# all count 4600
# all count 4700
# all count 4800
# Checking treshold 12
# all count 4900
# all count 5000
# all count 5100
# all count 5200
# Checking treshold 13
# all count 5300
# all count 5400
# all count 5500
# all count 5600
# Checking treshold 14
# all count 5700
# all count 5800
# all count 5900
# all count 6000
# Checking treshold 15
# all count 6100
# all count 6200
# all count 6300
# all count 6400
# Checking treshold 16
# all count 6500
# all count 6600
# all count 6700
# all count 6800
# Checking treshold 17
# all count 6900
# all count 7000
# all count 7100
# all count 7200
# Checking treshold 18
# all count 7300
# all count 7400
# all count 7500
# all count 7600
# Checking treshold 19
# all count 7700
# all count 7800
# all count 7900
# all count 8000
# Checking treshold 20
# all count 8100
# all count 8200
# all count 8300
# all count 8400
# Checking treshold 21
# all count 8500
# all count 8600
# all count 8700
# all count 8800
# Checking treshold 22
# all count 8900
# all count 9000
# all count 9100
# all count 9200
# Checking treshold 23
# all count 9300
# all count 9400
# all count 9500
# all count 9600
# Checking treshold 24
# all count 9700
# all count 9800
# all count 9900
# all count 10000
# Checking treshold 25
# all count 10100
# all count 10200
# all count 10300
# all count 10400
# Checking treshold 26
# all count 10500
# all count 10600
# all count 10700
# all count 10800
# Checking treshold 27
# all count 10900
# all count 11000
# all count 11100
# all count 11200
# Checking treshold 28
# all count 11300
# all count 11400
# all count 11500
# all count 11600
# Checking treshold 29
# all count 11700
# all count 11800
# all count 11900
# all count 12000
# Checking treshold 30
# all count 12100
# all count 12200
# all count 12300
# all count 12400
# Checking treshold 31
# all count 12500
# all count 12600
# all count 12700
# all count 12800
# Checking treshold 32
# all count 12900
# all count 13000
# all count 13100
# all count 13200
# Checking treshold 33
# all count 13300
# all count 13400
# all count 13500
# all count 13600
# Checking treshold 34
# all count 13700
# all count 13800
# all count 13900
# all count 14000
# Checking treshold 35
# all count 14100
# all count 14200
# all count 14300
# all count 14400
# Checking treshold 36
# all count 14500
# all count 14600
# all count 14700
# all count 14800
# Checking treshold 37
# all count 14900
# all count 15000
# all count 15100
# all count 15200
# Checking treshold 38
# all count 15300
# all count 15400
# all count 15500
# all count 15600
# Checking treshold 39
# all count 15700
# all count 15800
# all count 15900
# all count 16000
# Checking treshold 40
# all count 16100
# all count 16200
# all count 16300
# all count 16400
# Checking treshold 41
# all count 16500
# all count 16600
# all count 16700
# all count 16800
# Checking treshold 42
# all count 16900
# all count 17000
# all count 17100
# all count 17200
# Checking treshold 43
# all count 17300
# all count 17400
# all count 17500
# all count 17600
# Checking treshold 44
# all count 17700
# all count 17800
# all count 17900
# all count 18000
# Checking treshold 45
# all count 18100
# all count 18200
# all count 18300
# all count 18400
# Checking treshold 46
# all count 18500
# all count 18600
# all count 18700
# all count 18800
# Checking treshold 47
# all count 18900
# all count 19000
# all count 19100
# all count 19200
# Checking treshold 48
# all count 19300
# all count 19400
# all count 19500
# all count 19600
# Checking treshold 49
# all count 19700
# all count 19800
# all count 19900
# all count 20000
# Checking treshold 50
# all count 20100
# all count 20200
# all count 20300
# all count 20400
# Checking treshold 51
# all count 20500
# all count 20600
# all count 20700
# all count 20800
# Checking treshold 52
# all count 20900
# all count 21000
# all count 21100
# all count 21200
# Checking treshold 53
# all count 21300
# all count 21400
# all count 21500
# all count 21600
# Checking treshold 54
# all count 21700
# all count 21800
# all count 21900
# all count 22000
# Checking treshold 55
# all count 22100
# all count 22200
# all count 22300
# all count 22400
# Checking treshold 56
# all count 22500
# all count 22600
# all count 22700
# all count 22800
# Checking treshold 57
# all count 22900
# all count 23000
# all count 23100
# all count 23200
# Checking treshold 58
# all count 23300
# all count 23400
# all count 23500
# all count 23600
# Checking treshold 59
# all count 23700
# all count 23800
# all count 23900
# all count 24000
# Checking treshold 60
# all count 24100
# all count 24200
# all count 24300
# all count 24400
# Checking treshold 61
# all count 24500
# all count 24600
# all count 24700
# all count 24800
# Checking treshold 62
# all count 24900
# all count 25000
# all count 25100
# all count 25200
# Checking treshold 63
# all count 25300
# all count 25400
# all count 25500
# all count 25600
# Checking treshold 64
# all count 25700
# all count 25800
# all count 25900
# all count 26000
# Checking treshold 65
# all count 26100
# all count 26200
# all count 26300
# all count 26400
# Checking treshold 66
# all count 26500
# all count 26600
# all count 26700
# all count 26800
# Checking treshold 67
# all count 26900
# all count 27000
# all count 27100
# all count 27200
# Checking treshold 68
# all count 27300
# all count 27400
# all count 27500
# all count 27600
# Checking treshold 69
# all count 27700
# all count 27800
# all count 27900
# all count 28000
# Checking treshold 70
# all count 28100
# all count 28200
# all count 28300
# all count 28400
# Checking treshold 71
# all count 28500
# all count 28600
# all count 28700
# all count 28800
# Checking treshold 72
# all count 28900
# all count 29000
# all count 29100
# all count 29200
# Checking treshold 73
# all count 29300
# all count 29400
# all count 29500
# all count 29600
# Checking treshold 74
# all count 29700
# all count 29800
# all count 29900
# all count 30000
# Checking treshold 75
# all count 30100
# all count 30200
# all count 30300
# all count 30400
# Checking treshold 76
# all count 30500
# all count 30600
# all count 30700
# all count 30800
# Checking treshold 77
# all count 30900
# all count 31000
# all count 31100
# all count 31200
# Checking treshold 78
# all count 31300
# all count 31400
# all count 31500
# all count 31600
# Checking treshold 79
# all count 31700
# all count 31800
# all count 31900
# all count 32000
# Checking treshold 80
# all count 32100
# all count 32200
# all count 32300
# all count 32400
# Checking treshold 81
# all count 32500
# all count 32600
# all count 32700
# all count 32800
# Checking treshold 82
# all count 32900
# all count 33000
# all count 33100
# all count 33200
# Checking treshold 83
# all count 33300
# all count 33400
# all count 33500
# all count 33600
# Checking treshold 84
# all count 33700
# all count 33800
# all count 33900
# all count 34000
# Checking treshold 85
# all count 34100
# all count 34200
# all count 34300
# all count 34400
# Checking treshold 86
# all count 34500
# all count 34600
# all count 34700
# all count 34800
# Checking treshold 87
# all count 34900
# all count 35000
# all count 35100
# all count 35200
# Checking treshold 88
# all count 35300
# all count 35400
# all count 35500
# all count 35600
# Checking treshold 89
# all count 35700
# all count 35800
# all count 35900
# all count 36000
# Checking treshold 90
# all count 36100
# all count 36200
# all count 36300
# all count 36400
# Checking treshold 91
# all count 36500
# all count 36600
# all count 36700
# all count 36800
# Checking treshold 92
# all count 36900
# all count 37000
# all count 37100
# all count 37200
# Checking treshold 93
# all count 37300
# all count 37400
# all count 37500
# all count 37600
# Checking treshold 94
# all count 37700
# all count 37800
# all count 37900
# all count 38000
# Checking treshold 95
# all count 38100
# all count 38200
# all count 38300
# all count 38400
# Checking treshold 96
# all count 38500
# all count 38600
# all count 38700
# all count 38800
# Checking treshold 97
# all count 38900
# all count 39000
# all count 39100
# all count 39200
# Checking treshold 98
# all count 39300
# all count 39400
# all count 39500
# all count 39600
# Checking treshold 99
# all count 39700
# all count 39800
# all count 39900
# all count 40000
# Checking treshold 100
# all count 40100
# all count 40200
# all count 40300
# all count 40400
# Checking treshold 101
# all count 40500
# all count 40600
# all count 40700
# all count 40800
# Checking treshold 102
# all count 40900
# all count 41000
# all count 41100
# all count 41200
# Checking treshold 103
# all count 41300
# all count 41400
# all count 41500
# all count 41600
# Checking treshold 104
# all count 41700
# all count 41800
# all count 41900
# all count 42000
# Checking treshold 105
# all count 42100
# all count 42200
# all count 42300
# all count 42400
# Checking treshold 106
# all count 42500
# all count 42600
# all count 42700
# all count 42800
# Checking treshold 107
# all count 42900
# all count 43000
# all count 43100
# all count 43200
# Checking treshold 108
# all count 43300
# all count 43400
# all count 43500
# all count 43600
# Checking treshold 109
# all count 43700
# all count 43800
# all count 43900
# all count 44000
# Checking treshold 110
# all count 44100
# all count 44200
# all count 44300
# all count 44400
# Checking treshold 111
# all count 44500
# all count 44600
# all count 44700
# all count 44800
# Checking treshold 112
# all count 44900
# all count 45000
# all count 45100
# all count 45200
# Checking treshold 113
# all count 45300
# all count 45400
# all count 45500
# all count 45600
# Checking treshold 114
# all count 45700
# all count 45800
# all count 45900
# all count 46000
# Checking treshold 115
# all count 46100
# all count 46200
# all count 46300
# all count 46400
# Checking treshold 116
# all count 46500
# all count 46600
# all count 46700
# all count 46800
# Checking treshold 117
# all count 46900
# all count 47000
# all count 47100
# all count 47200
# Checking treshold 118
# all count 47300
# all count 47400
# all count 47500
# all count 47600
# Checking treshold 119
# all count 47700
# all count 47800
# all count 47900
# all count 48000
# Checking treshold 120
# all count 48100
# all count 48200
# all count 48300
# all count 48400
# Checking treshold 121
# all count 48500
# all count 48600
# all count 48700
# all count 48800
# Checking treshold 122
# all count 48900
# all count 49000
# all count 49100
# all count 49200
# Checking treshold 123
# all count 49300
# all count 49400
# all count 49500
# all count 49600
# Checking treshold 124
# all count 49700
# all count 49800
# all count 49900
# all count 50000
# Checking treshold 125
# all count 50100
# all count 50200
# all count 50300
# all count 50400
# Checking treshold 126
# all count 50500
# all count 50600
# all count 50700
# all count 50800
# Checking treshold 127
# all count 50900
# all count 51000
# all count 51100
# all count 51200
# Checking treshold 128
# all count 51300
# all count 51400
# all count 51500
# all count 51600
# Checking treshold 129
# all count 51700
# all count 51800
# all count 51900
# all count 52000
# Checking treshold 130
# all count 52100
# all count 52200
# all count 52300
# all count 52400
# Checking treshold 131
# all count 52500
# all count 52600
# all count 52700
# all count 52800
# Checking treshold 132
# all count 52900
# all count 53000
# all count 53100
# all count 53200
# Checking treshold 133
# all count 53300
# all count 53400
# all count 53500
# all count 53600
# Checking treshold 134
# all count 53700
# all count 53800
# all count 53900
# all count 54000
# Checking treshold 135
# all count 54100
# all count 54200
# all count 54300
# all count 54400
# Checking treshold 136
# all count 54500
# all count 54600
# all count 54700
# all count 54800
# Checking treshold 137
# all count 54900
# all count 55000
# all count 55100
# all count 55200
# Checking treshold 138
# all count 55300
# all count 55400
# all count 55500
# all count 55600
# Checking treshold 139
# all count 55700
# all count 55800
# all count 55900
# all count 56000
# Checking treshold 140
# all count 56100
# all count 56200
# all count 56300
# all count 56400
# Checking treshold 141
# all count 56500
# all count 56600
# all count 56700
# all count 56800
# Checking treshold 142
# all count 56900
# all count 57000
# all count 57100
# all count 57200
# Checking treshold 143
# all count 57300
# all count 57400
# all count 57500
# all count 57600
# Checking treshold 144
# all count 57700
# all count 57800
# all count 57900
# all count 58000
# Checking treshold 145
# all count 58100
# all count 58200
# all count 58300
# all count 58400
# Checking treshold 146
# all count 58500
# all count 58600
# all count 58700
# all count 58800
# Checking treshold 147
# all count 58900
# all count 59000
# all count 59100
# all count 59200
# Checking treshold 148
# all count 59300
# all count 59400
# all count 59500
# all count 59600
# Checking treshold 149
# all count 59700
# all count 59800
# all count 59900
# all count 60000
# Checking treshold 150
# all count 60100
# all count 60200
# all count 60300
# all count 60400
# Checking treshold 151
# all count 60500
# all count 60600
# all count 60700
# all count 60800
# Checking treshold 152
# all count 60900
# all count 61000
# all count 61100
# all count 61200
# Checking treshold 153
# all count 61300
# all count 61400
# all count 61500
# all count 61600
# Checking treshold 154
# all count 61700
# all count 61800
# all count 61900
# all count 62000
# Checking treshold 155
# all count 62100
# all count 62200
# all count 62300
# all count 62400
# Checking treshold 156
# all count 62500
# all count 62600
# all count 62700
# all count 62800
# Checking treshold 157
# all count 62900
# all count 63000
# all count 63100
# all count 63200
# Checking treshold 158
# all count 63300
# all count 63400
# all count 63500
# all count 63600
# Checking treshold 159
# all count 63700
# all count 63800
# all count 63900
# all count 64000
# Checking treshold 160
# all count 64100
# all count 64200
# all count 64300
# all count 64400
# Checking treshold 161
# all count 64500
# all count 64600
# all count 64700
# all count 64800
# Checking treshold 162
# all count 64900
# all count 65000
# all count 65100
# all count 65200
# Checking treshold 163
# all count 65300
# all count 65400
# all count 65500
# all count 65600
# Checking treshold 164
# all count 65700
# all count 65800
# all count 65900
# all count 66000
# Checking treshold 165
# all count 66100
# all count 66200
# all count 66300
# all count 66400
# Checking treshold 166
# all count 66500
# all count 66600
# all count 66700
# all count 66800
# Checking treshold 167
# all count 66900
# all count 67000
# all count 67100
# all count 67200
# Checking treshold 168
# all count 67300
# all count 67400
# all count 67500
# all count 67600
# Checking treshold 169
# all count 67700
# all count 67800
# all count 67900
# all count 68000
# Checking treshold 170
# all count 68100
# all count 68200
# all count 68300
# all count 68400
# Checking treshold 171
# all count 68500
# all count 68600
# all count 68700
# all count 68800
# Checking treshold 172
# all count 68900
# all count 69000
# all count 69100
# all count 69200
# Checking treshold 173
# all count 69300
# all count 69400
# all count 69500
# all count 69600
# Checking treshold 174
# all count 69700
# all count 69800
# all count 69900
# all count 70000
# Checking treshold 175
# all count 70100
# all count 70200
# all count 70300
# all count 70400
# Checking treshold 176
# all count 70500
# all count 70600
# all count 70700
# all count 70800
# Checking treshold 177
# all count 70900
# all count 71000
# all count 71100
# all count 71200
# Checking treshold 178
# all count 71300
# all count 71400
# all count 71500
# all count 71600
# Checking treshold 179
# all count 71700
# all count 71800
# all count 71900
# all count 72000
# Checking treshold 180
# all count 72100
# all count 72200
# all count 72300
# all count 72400
# Checking treshold 181
# all count 72500
# all count 72600
# all count 72700
# all count 72800
# Checking treshold 182
# all count 72900
# all count 73000
# all count 73100
# all count 73200
# Checking treshold 183
# all count 73300
# all count 73400
# all count 73500
# all count 73600
# Checking treshold 184
# all count 73700
# all count 73800
# all count 73900
# all count 74000
# Checking treshold 185
# all count 74100
# all count 74200
# all count 74300
# all count 74400
# Checking treshold 186
# all count 74500
# all count 74600
# all count 74700
# all count 74800
# Checking treshold 187
# all count 74900
# all count 75000
# all count 75100
# all count 75200
# Checking treshold 188
# all count 75300
# all count 75400
# all count 75500
# all count 75600
# Checking treshold 189
# all count 75700
# all count 75800
# all count 75900
# all count 76000
# Checking treshold 190
# all count 76100
# all count 76200
# all count 76300
# all count 76400
# Checking treshold 191
# all count 76500
# all count 76600
# all count 76700
# all count 76800
# Checking treshold 192
# all count 76900
# all count 77000
# all count 77100
# all count 77200
# Checking treshold 193
# all count 77300
# all count 77400
# all count 77500
# all count 77600
# Checking treshold 194
# all count 77700
# all count 77800
# all count 77900
# all count 78000
# Checking treshold 195
# all count 78100
# all count 78200
# all count 78300
# all count 78400
# Checking treshold 196
# all count 78500
# all count 78600
# all count 78700
# all count 78800
# Checking treshold 197
# all count 78900
# all count 79000
# all count 79100
# all count 79200
# Checking treshold 198
# all count 79300
# all count 79400
# all count 79500
# all count 79600
# Checking treshold 199
# all count 79700
# all count 79800
# all count 79900
# all count 80000
# Checking treshold 200
# all count 80100
# all count 80200
# all count 80300
# all count 80400
# Checking treshold 201
# all count 80500
# all count 80600
# all count 80700
# all count 80800
# Checking treshold 202
# all count 80900
# all count 81000
# all count 81100
# all count 81200
# Checking treshold 203
# all count 81300
# all count 81400
# all count 81500
# all count 81600
# Checking treshold 204
# all count 81700
# all count 81800
# all count 81900
# all count 82000
# Checking treshold 205
# all count 82100
# all count 82200
# all count 82300
# all count 82400
# Checking treshold 206
# all count 82500
# all count 82600
# all count 82700
# all count 82800
# Checking treshold 207
# all count 82900
# all count 83000
# all count 83100
# all count 83200
# Checking treshold 208
# all count 83300
# all count 83400
# all count 83500
# all count 83600
# Checking treshold 209
# all count 83700
# all count 83800
# all count 83900
# all count 84000
# Checking treshold 210
# all count 84100
# all count 84200
# all count 84300
# all count 84400
# Checking treshold 211
# all count 84500
# all count 84600
# all count 84700
# all count 84800
# Checking treshold 212
# all count 84900
# all count 85000
# all count 85100
# all count 85200
# Checking treshold 213
# all count 85300
# all count 85400
# all count 85500
# all count 85600
# Checking treshold 214
# all count 85700
# all count 85800
# all count 85900
# all count 86000
# Checking treshold 215
# all count 86100
# all count 86200
# all count 86300
# all count 86400
# Checking treshold 216
# all count 86500
# all count 86600
# all count 86700
# all count 86800
# Checking treshold 217
# all count 86900
# all count 87000
# all count 87100
# all count 87200
# Checking treshold 218
# all count 87300
# all count 87400
# all count 87500
# all count 87600
# Checking treshold 219
# all count 87700
# all count 87800
# all count 87900
# all count 88000
# Checking treshold 220
# all count 88100
# all count 88200
# all count 88300
# all count 88400
# Checking treshold 221
# all count 88500
# all count 88600
# all count 88700
# all count 88800
# Checking treshold 222
# all count 88900
# all count 89000
# all count 89100
# all count 89200
# Checking treshold 223
# all count 89300
# all count 89400
# all count 89500
# all count 89600
# Checking treshold 224
# all count 89700
# all count 89800
# all count 89900
# all count 90000
# Checking treshold 225
# all count 90100
# all count 90200
# all count 90300
# all count 90400
# Checking treshold 226
# all count 90500
# all count 90600
# all count 90700
# all count 90800
# Checking treshold 227
# all count 90900
# all count 91000
# all count 91100
# all count 91200
# Checking treshold 228
# all count 91300
# all count 91400
# all count 91500
# all count 91600
# Checking treshold 229
# all count 91700
# all count 91800
# all count 91900
# all count 92000
# Checking treshold 230
# all count 92100
# all count 92200
# all count 92300
# all count 92400
# Checking treshold 231
# all count 92500
# all count 92600
# all count 92700
# all count 92800
# Checking treshold 232
# all count 92900
# all count 93000
# all count 93100
# all count 93200
# Checking treshold 233
# all count 93300
# all count 93400
# all count 93500
# all count 93600
# Checking treshold 234
# all count 93700
# all count 93800
# all count 93900
# all count 94000
# Checking treshold 235
# all count 94100
# all count 94200
# all count 94300
# all count 94400
# Checking treshold 236
# all count 94500
# all count 94600
# all count 94700
# all count 94800
# Checking treshold 237
# all count 94900
# all count 95000
# all count 95100
# all count 95200
# Checking treshold 238
# all count 95300
# all count 95400
# all count 95500
# all count 95600
# Checking treshold 239
# all count 95700
# all count 95800
# all count 95900
# all count 96000
# Checking treshold 240
# all count 96100
# all count 96200
# all count 96300
# all count 96400
# Checking treshold 241
# all count 96500
# all count 96600
# all count 96700
# all count 96800
# Checking treshold 242
# all count 96900
# all count 97000
# all count 97100
# all count 97200
# Checking treshold 243
# all count 97300
# all count 97400
# all count 97500
# all count 97600
# Checking treshold 244
# all count 97700
# all count 97800
# all count 97900
# all count 98000
# Checking treshold 245
# all count 98100
# all count 98200
# all count 98300
# all count 98400
# Checking treshold 246
# all count 98500
# all count 98600
# all count 98700
# all count 98800
# Checking treshold 247
# all count 98900
# all count 99000
# all count 99100
# all count 99200
# Checking treshold 248
# all count 99300
# all count 99400
# all count 99500
# all count 99600
# Checking treshold 249
# all count 99700
# all count 99800
# all count 99900
# all count 100000
# Checking treshold 250
# all count 100100
# all count 100200
# all count 100300
# all count 100400
# Checking treshold 251
# all count 100500
# all count 100600
# all count 100700
# all count 100800
# Checking treshold 252
# all count 100900
# all count 101000
# all count 101100
# all count 101200
# Checking treshold 253
# all count 101300
# all count 101400
# all count 101500
# all count 101600
# Checking treshold 254
# all count 101700
# all count 101800
# all count 101900
# all count 102000

# %%
dump_to_pickle(all_results, 'd:/all_treshold_results_2.pickle')

# %%
all_ratios = []
ixs = []

for k in all_results.keys():
    res = all_results[k]
    correct_sum = 0
    all_sum = 0
    ixs.append(k)
    for t in res:
        correct_sum = t[0]
        all_sum = t[2]
    ratio = correct_sum * 1.0 / all_sum
    all_ratios.append(ratio)

# %%
all_results[0][0]
# Out:
# (322762.0, 7198.0, 329960, 329960.0)

# %%
plt.plot(ixs, all_ratios)

# %%
filtered_ratios = [all_ratios[ix] for ix in ixs if ix >= 50 and ix <= 150]
filtered_ixs = [ix for ix in ixs if ix >= 50 and ix <= 150]

# %%
plt.plot(filtered_ixs, filtered_ratios)

# %%
np.argmax(all_ratios)
# Out:
# 98

# %%
img = cv2.imread('c:/Users/ax/retina-unet-master-disc/test/all_predictions.png')
ret_val, img_out = cv2.threshold(img, 98, 255, cv2.THRESH_BINARY)
cv2.imwrite('c:/Users/ax/retina-unet-master-disc/test/all_predictions_erode_.png', img_out)
# Out:
# True

# %%
all_ratios[98]
# Out:
# 0.9989453267062675

# %%
#treshold 98
