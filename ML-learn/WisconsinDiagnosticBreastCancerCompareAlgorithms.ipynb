# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
df = pd.read_csv("q:/Data.3/python-machine-learning-book-master/code/datasets/wdbc/wdbc.csv")

# %%
def convert_symbol_to_value(x):
    if x == "M":
        return 0
    else:
        return 1

# %%
df['diagnosis_num'] = df["Diagnosis"].apply(lambda x: convert_symbol_to_value(x))

# %%
df.head()
# Out:
#          Id Diagnosis     f1     f2      f3      f4       f5       f6      f7  \
# 0    842302         M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517         M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903         M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301         M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402         M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         f8  ...    f22     f23     f24     f25     f26     f27     f28  \
# 0  0.14710  ...  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#       f29      f30  diagnosis_num
# 0  0.4601  0.11890              0
# ...

# %%
y = df["diagnosis_num"]

# %%
X = df[["f1","f2","f3","f4","f5","f6","f7","f8","f9","f10","f11","f12","f13","f14","f15","f16","f17","f18","f19","f20","f21","f22","f23","f24","f25","f26","f27","f28","f29","f30"]]

# %%
models = [
    RandomForestClassifier(n_estimators=20, random_state=0),
    KNeighborsClassifier(n_neighbors=7, algorithm='ball_tree'),
    LogisticRegression(random_state=4669),
    SVC(kernel='linear')
]

# %%
def learn_and_evaluate(models, X, y, test_size):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=4669)
    
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    for model in models:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        print(model)
        print(metrics.accuracy_score(y_test, y_pred))

# %%
learn_and_evaluate(models, X, y, 0.30)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)
# 0.9707602339181286
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')
# 0.9590643274853801
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
# ...
